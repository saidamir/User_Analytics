# %%
from datetime import datetime
import pandas as pd
import numpy as np

# %%
items = pd.read_csv('order_items.csv')[['id','order_id','product_id','quantity','created_at']]

# %%
items['created_at']=pd.to_datetime(items['created_at'])

# %% [markdown]
# Transforming datestamp to MM/YY to be suitable for cohorts

# %%
items['created_at_month_year']= items['created_at'].map(lambda x: x.strftime('%Y-%m'))

# %%
orders = pd.read_csv('orders.csv')[['id','customer_id','created_at']]

# %%
orders['created_at'] = pd.to_datetime(orders['created_at'])

# %%
orders['created_at_month_year']= orders['created_at'].map(lambda x: x.strftime('%Y-%m'))

# %%
cohort = orders.sort_values(by='created_at_month_year').groupby('customer_id')['created_at_month_year'].first()

# %%
cohort = cohort.to_frame(name='cohort') #need to transform the above pandas series to df

# %%
cohort.head()
# Out:
#               cohort
# customer_id
# 1            2013-04
# 2            2013-04
# 3            2013-04
# 4            2013-04
# 5            2013-04

# %% [markdown]
# #### We cannot join Orders and Order Items, as timestamps differ by two years. Also no foreign keys available, id, order_id differ
# see below

# %%
items.head()
# Out:
#    id  order_id  product_id  quantity          created_at  \
# 0   1         1           1         1 2015-04-02 12:00:00
# 1   2         2           6         1 2015-04-08 12:00:00
# 2   3         3           2         1 2015-04-05 12:00:00
# 3   4         4           1         1 2015-04-06 12:00:00
# 4   5         5           1         1 2015-04-02 12:00:00
#
#   created_at_month_year
# 0               2015-04
# 1               2015-04
# 2               2015-04
# 3               2015-04
# 4               2015-04

# %%
orders.head()
# Out:
#    id  customer_id          created_at created_at_month_year
# 0   1            1 2013-04-07 12:00:00               2013-04
# 1   2            2 2013-04-04 12:00:00               2013-04
# 2   3            4 2013-04-06 12:00:00               2013-04
# 3   4            3 2013-04-08 12:00:00               2013-04
# 4   5           10 2013-04-04 12:00:00               2013-04

# %%
products = pd.read_csv('products.csv')[['id','price','created_at']]

# %%
products['created_at']=pd.to_datetime(products['created_at'])

# %%
products['created_at_month_year']= products['created_at'].map(lambda x: x.strftime('%Y-%m'))

# %%
items.describe()
# Out:
#                  id      order_id     product_id  quantity
# count  665870.00000  665870.00000  665870.000000  665870.0
# mean   332935.50000  332935.50000       5.496139       1.0
# std    192220.25621  192220.25621       2.872268       0.0
# min         1.00000       1.00000       1.000000       1.0
# 25%    166468.25000  166468.25000       3.000000       1.0
# 50%    332935.50000  332935.50000       5.000000       1.0
# 75%    499402.75000  499402.75000       8.000000       1.0
# max    665870.00000  665870.00000      10.000000       1.0

# %%
products.head(1)
# Out:
#    id  price          created_at created_at_month_year
# 0   1   8999 2016-04-24 19:04:05               2016-04

# %%
type(products['price'])
# Out:
# pandas.core.series.Series

# %%
df_items = pd.merge(items[['product_id','order_id', 'quantity']],products[['id','price']],
                    how = 'left', left_on='product_id',right_on='id')

# %%
df_items.head(2)
# Out:
#    product_id  order_id  quantity  id  price
# 0           1         1         1   1   8999
# 1           6         2         1   6   7999

# %%
assert len(items) == len(df_items)

# %%
df_items['revenue']=df_items['quantity'] * df_items['price']

# %%
#cohort_short = cohort[cohort['cohort']>='2015-04']

# %%
#cohort_short.head(1)
# Out:
#               cohort
# customer_id
# 724060       2015-04

# %%
df_orders = pd.merge(df_items[['order_id','revenue']],orders[['customer_id','id']],
                     how = 'left', left_on='order_id',right_on='id')

# %%
df_orders.head()
# Out:
#    order_id  revenue  customer_id  id
# 0         1     8999            1   1
# 1         2     7999            2   2
# 2         3     4999            4   3
# 3         4     8999            3   4
# 4         5     8999           10   5

# %%
df_cohorts = pd.merge(df_orders[['customer_id', 'revenue']],
                      cohort.reset_index()[['customer_id','cohort']],
                      how = 'left', on='customer_id')

# %%
df_cohorts = pd.merge(df_cohorts[['customer_id', 'revenue','cohort']],
                      orders[['customer_id','created_at_month_year']],
                      how = 'left', on='customer_id')

# %%
df_cohorts.head()
# Out:
#    customer_id  revenue   cohort created_at_month_year
# 0            1     8999  2013-04               2013-04
# 1            1     8999  2013-04               2013-10
# 2            1     8999  2013-04               2015-03
# 3            1     8999  2013-04               2015-04
# 4            2     7999  2013-04               2013-04

# %% [markdown]
# We made two assumptions: Id in Orders corresponds to order_id in order_items
# and
# Cohort periods are based on orders.

# %%
cohort_pivot1 = pd.pivot_table(df_cohorts, values = 'revenue', 
               index = 'created_at_month_year', columns = 'cohort', aggfunc = 'sum')

# %%
cohort_pivot1
# Out:
# cohort                     2013-04      2013-05      2013-06      2013-07  \
# created_at_month_year
# 2013-04                528091201.0          NaN          NaN          NaN
# 2013-05                 87876474.0  539915881.0          NaN          NaN
# 2013-06                 88224179.0   89532341.0  496914537.0          NaN
# 2013-07                 90849810.0   95763461.0   87816593.0  483795773.0
# 2013-08                 94287409.0   95049098.0   90334131.0   86618977.0
# 2013-09                 92121400.0   93762416.0   85817966.0   86102889.0
# 2013-10                 93022845.0   96106599.0   88156095.0   90321119.0
# 2013-11                 90668871.0   91902178.0   86221062.0   87933195.0
# 2013-12                 92331510.0   97257771.0   89710135.0   87217236.0
# 2014-01                 97491682.0   94084174.0   90703289.0   89154562.0
# 2014-02                 81931501.0   84694300.0   83009716.0   80094121.0
# 2014-03                 93523130.0   98593383.0   93600193.0   91021495.0
# 2014-04                 83962580.0   85904452.0   78982079.0   77009321.0
# 2014-05                 65024610.0   66496689.0   62397305.0   60669003.0
# 2014-06                 61081880.0   65604799.0   60128244.0   58184369.0
# 2014-07                 66587373.0   68306017.0   60497428.0   57525222.0
# 2014-08                 68341303.0   64177596.0   60984701.0   59314418.0
# 2014-09                 64651839.0   65244711.0   59821566.0   57260961.0
# 2014-10                 64823355.0   67367862.0   63020523.0   58348189.0
# 2014-11                 62219211.0   63760035.0   57842734.0   57868430.0
# 2014-12                 66547717.0   67268241.0   61401927.0   61416213.0
# 2015-01                 64988224.0   66089434.0   60078965.0   60174464.0
# 2015-02                 59495057.0   60138467.0   53909690.0   53856284.0
# 2015-03                 65829914.0   68275018.0   62671975.0   63140038.0
# 2015-04                 64571219.0   65514583.0   59877843.0   55475976.0
# 2015-05                 65598754.0   67331258.0   60003650.0   59750511.0
# 2015-06                 64955082.0   65896316.0   60162512.0   57882825.0
# 2015-07                 66290126.0   63772548.0   59902894.0   59100719.0
# 2015-08                 65169573.0   67043573.0   62843536.0   60069649.0
# 2013-08                        NaN          NaN          NaN          NaN
# 2013-09                        NaN          NaN          NaN          NaN
# 2013-10                        NaN          NaN          NaN          NaN
# 2013-11                        NaN          NaN          NaN          NaN
# 2013-12                341575182.0          NaN          NaN          NaN
# 2014-01                 67889657.0  312836900.0          NaN          NaN
# 2014-02                 62099142.0   58398369.0  253552069.0          NaN
# 2014-03                 75154636.0   69430188.0   55509639.0  269075573.0
# 2014-04                 62578596.0   57566875.0   48836704.0   53612880.0
# 2014-05                 40208372.0   37581730.0   30662492.0   32026639.0
# 2014-06                 40859204.0   37538592.0   29965450.0   31985955.0
# 2014-07                 42612346.0   39790920.0   29623542.0   32572926.0
# 2014-08                 40977218.0   37850824.0   30429156.0   33415767.0
# 2014-09                 40305225.0   37799772.0   31118605.0   31541103.0
# 2014-10                 42863950.0   39056926.0   31012940.0   33240200.0
# 2014-11                 40798175.0   37121719.0   30203637.0   31703578.0
# 2014-12                 41322044.0   38089896.0   31696582.0   33100119.0
# 2015-01                 43990769.0   39080902.0   31406599.0   32629969.0
# 2015-02                 37849038.0   35942253.0   28271957.0   30089589.0
# 2015-03                 43252838.0   39764591.0   31708815.0   34398918.0
# 2015-04                 40432867.0   37143358.0   29808877.0   32948563.0
# 2015-05                 42304836.0   38953128.0   30993008.0   33045510.0
# 2015-06                 41785138.0   37096920.0   30553341.0   31724794.0
# 2015-07                 40649529.0   38045320.0   30725401.0   33327528.0
# 2015-08                 42067195.0   37849626.0   30813945.0   33825843.0
# 2015-09                 39615283.0   37748706.0   30098977.0   31763246.0
# 2015-10                 42187940.0   38238820.0   31927267.0   32591581.0
# 2015-11                 40526718.0   37336908.0   30271707.0   31675209.0
# 2015-12                 43658364.0   41005519.0   31678831.0   31687572.0
# 2016-01                 42664156.0   38392294.0   31286615.0   33297592.0
# 2016-02                 39768172.0   35878017.0   28658478.0   30396242.0
# 2016-03                 41949531.0   38477656.0   31520905.0   32087452.0
# 2016-04                 36750431.0   34883793.0   27023091.0   27909504.0
#
# cohort                     2014-04
# created_at_month_year
# 2013-04                        NaN
# 2013-05                        NaN
# 2013-06                        NaN
# 2013-07                        NaN
# 2013-08                        NaN
# 2013-09                        NaN
# 2013-10                        NaN
# 2013-11                        NaN
# 2013-12                        NaN
# 2014-01                        NaN
# 2014-02                        NaN
# 2014-03                        NaN
# 2014-04                188724890.0
# 2014-05                 21826067.0
# 2014-06                 22270818.0
# 2014-07                 23952990.0
# 2014-08                 23033432.0
# 2014-09                 22228652.0
# 2014-10                 22647967.0
# 2014-11                 22591560.0
# 2014-12                 23205939.0
# 2015-01                 23145033.0
# 2015-02                 20775732.0
# 2015-03                 23498325.0
# 2015-04                 22191672.0
# 2015-05                 23082605.0
# 2015-06                 22898652.0
# 2015-07                 23412520.0
# 2015-08                 23370706.0
# 2015-09                 22417118.0
# 2015-10                 22934412.0
# 2015-11                 21958263.0
# 2015-12                 23085919.0
# 2016-01                 22915238.0
# 2016-02                 22267745.0
# 2016-03                 23200430.0
# 2016-04                 20206194.0

# %%
cohort_pivot1.to_csv('Revenue_Cohorts.csv')
